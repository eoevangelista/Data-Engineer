# %% [markdown]
# ***Install and manage software packages for the exercice***

# %%
# !pip install ibge # package from Pypi (Collection of APIs for the IBGE [Brazilian Institute of Geography and Statistics] Data Services in Brazil)
# !pip install boto3 # For connection with AWS S3
# !pip install pymongo[srv] # For connection with mongodb in cloud.
# Out:
# Collecting ibge
#   Downloading https://files.pythonhosted.org/packages/7a/99/64971f16ea3ac11581b2f3d96be29b47a722371d91f12ce85f575aada7d2/ibge-0.0.5-py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from ibge) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->ibge) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->ibge) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->ibge) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->ibge) (3.0.4)
# Installing collected packages: ibge
# Successfully installed ibge-0.0.5
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/e2/4b/d16d94af2a53cdce2c1f59026938fe2b15e40a3e8b3db3fcbb371c1b75ea/boto3-1.17.4-py2.py3-none-any.whl (130kB)
#      |████████████████████████████████| 133kB 6.0MB/s
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/ea/43/4b4a1b26eb03a429a4c37ca7fdf369d938bd60018fc194e94b8379b0c77c/s3transfer-0.3.4-py2.py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 4.0MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting botocore<1.21.0,>=1.20.4
#   Downloading https://files.pythonhosted.org/packages/7b/81/2450e2b7f6ff15bfcbf9a60992a9a32a68d378ee18ee74f79c7034ea882c/botocore-1.20.4-py2.py3-none-any.whl (7.2MB)
#      |████████████████████████████████| 7.2MB 7.3MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.21.0,>=1.20.4->boto3) (2.8.1)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading https://files.pythonhosted.org/packages/23/fc/8a49991f7905261f9ca9df5aa9b58363c3c821ce3e7f671895442b7100f2/urllib3-1.26.3-py2.py3-none-any.whl (137kB)
#      |████████████████████████████████| 143kB 43.6MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.4->boto3) (1.15.0)
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.3 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed boto3-1.17.4 botocore-1.20.4 jmespath-0.10.0 s3transfer-0.3.4 urllib3-1.26.3
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.6/dist-packages (3.11.3)
# Collecting dnspython<2.0.0,>=1.16.0; extra == "srv"
#   Downloading https://files.pythonhosted.org/packages/ec/d3/3aa0e7213ef72b8585747aa0e271a9523e713813b9a20177ebe1e939deb0/dnspython-1.16.0-py2.py3-none-any.whl (188kB)
#      |████████████████████████████████| 194kB 4.9MB/s
# Installing collected packages: dnspython
# Successfully installed dnspython-1.16.0

# %% [markdown]
# **Importing modules to be used**

# %%
from bson.json_util import dumps
from ibge.localidades import *
import boto3
import json
import pymongo
# Out:
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# **Assigning and testing ibge loading**

# %%
dataRegiao = Regioes()
dataRegiao.count()
# Out:
# 5

# %%
dataEstado = Estados()
dataEstado.count()
# Out:
# 27

# %%
dataMunicipio = Municipios()
dataMunicipio.count()
# Out:
# 5570

# %%
dataRegiao.json()
# Out:
# [{'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#  {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#  {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#  {'id': 4, 'nome': 'Sul', 'sigla': 'S'},
#  {'id': 5, 'nome': 'Centro-Oeste', 'sigla': 'CO'}]

# %%
dataEstado.json()
# Out:
# [{'id': 11,
#   'nome': 'Rondônia',
#   'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#   'sigla': 'RO'},
#  {'id': 12,
#   'nome': 'Acre',
#   'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#   'sigla': 'AC'},
#  {'id': 13,
#   'nome': 'Amazonas',
#   'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#   'sigla': 'AM'},
#  {'id': 14,
#   'nome': 'Roraima',
#   'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#   'sigla': 'RR'},
#  {'id': 15,
#   'nome': 'Pará',
#   'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#   'sigla': 'PA'},
#  {'id': 16,
#   'nome': 'Amapá',
#   'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#   'sigla': 'AP'},
#  {'id': 17,
#   'nome': 'Tocantins',
#   'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#   'sigla': 'TO'},
#  {'id': 21,
#   'nome': 'Maranhão',
#   'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#   'sigla': 'MA'},
#  {'id': 22,
#   'nome': 'Piauí',
#   'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#   'sigla': 'PI'},
#  {'id': 23,
#   'nome': 'Ceará',
#   'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#   'sigla': 'CE'},
#  {'id': 24,
#   'nome': 'Rio Grande do Norte',
#   'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#   'sigla': 'RN'},
#  {'id': 25,
#   'nome': 'Paraíba',
#   'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#   'sigla': 'PB'},
#  {'id': 26,
#   'nome': 'Pernambuco',
#   'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#   'sigla': 'PE'},
#  {'id': 27,
#   'nome': 'Alagoas',
#   'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#   'sigla': 'AL'},
#  {'id': 28,
#   'nome': 'Sergipe',
#   'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#   'sigla': 'SE'},
#  {'id': 29,
#   'nome': 'Bahia',
#   'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#   'sigla': 'BA'},
#  {'id': 31,
#   'nome': 'Minas Gerais',
#   'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#   'sigla': 'MG'},
#  {'id': 32,
#   'nome': 'Espírito Santo',
#   'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#   'sigla': 'ES'},
#  {'id': 33,
#   'nome': 'Rio de Janeiro',
#   'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#   'sigla': 'RJ'},
#  {'id': 35,
#   'nome': 'São Paulo',
#   'regiao': {'id': 3, 'nome': 'Sudeste', 'sigla': 'SE'},
#   'sigla': 'SP'},
#  {'id': 41,
#   'nome': 'Paraná',
#   'regiao': {'id': 4, 'nome': 'Sul', 'sigla': 'S'},
#   'sigla': 'PR'},
#  {'id': 42,
#   'nome': 'Santa Catarina',
#   'regiao': {'id': 4, 'nome': 'Sul', 'sigla': 'S'},
#   'sigla': 'SC'},
#  {'id': 43,
#   'nome': 'Rio Grande do Sul',
#   'regiao': {'id': 4, 'nome': 'Sul', 'sigla': 'S'},
#   'sigla': 'RS'},
#  {'id': 50,
#   'nome': 'Mato Grosso do Sul',
#   'regiao': {'id': 5, 'nome': 'Centro-Oeste', 'sigla': 'CO'},
#   'sigla': 'MS'},
#  {'id': 51,
#   'nome': 'Mato Grosso',
#   'regiao': {'id': 5, 'nome': 'Centro-Oeste', 'sigla': 'CO'},
#   'sigla': 'MT'},
#  {'id': 52,
#   'nome': 'Goiás',
#   'regiao': {'id': 5, 'nome': 'Centro-Oeste', 'sigla': 'CO'},
#   'sigla': 'GO'},
#  {'id': 53,
#   'nome': 'Distrito Federal',
#   'regiao': {'id': 5, 'nome': 'Centro-Oeste', 'sigla': 'CO'},
#   'sigla': 'DF'}]

# %%
dataMunicipio.json()
# Out:
# [{'id': 1100015,
#   'microrregiao': {'id': 11006,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Cacoal'},
#   'nome': "Alta Floresta D'Oeste",
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100023,
#   'microrregiao': {'id': 11003,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ariquemes'},
#   'nome': 'Ariquemes',
#   'regiao-imediata': {'id': 110002,
#    'nome': 'Ariquemes',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100031,
#   'microrregiao': {'id': 11008,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Colorado do Oeste'},
#   'nome': 'Cabixi',
#   'regiao-imediata': {'id': 110006,
#    'nome': 'Vilhena',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100049,
#   'microrregiao': {'id': 11006,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Cacoal'},
#   'nome': 'Cacoal',
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100056,
#   'microrregiao': {'id': 11008,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Colorado do Oeste'},
#   'nome': 'Cerejeiras',
#   'regiao-imediata': {'id': 110006,
#    'nome': 'Vilhena',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100064,
#   'microrregiao': {'id': 11008,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Colorado do Oeste'},
#   'nome': 'Colorado do Oeste',
#   'regiao-imediata': {'id': 110006,
#    'nome': 'Vilhena',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100072,
#   'microrregiao': {'id': 11008,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Colorado do Oeste'},
#   'nome': 'Corumbiara',
#   'regiao-imediata': {'id': 110006,
#    'nome': 'Vilhena',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100080,
#   'microrregiao': {'id': 11002,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Madeira-Guaporé'},
#    'nome': 'Guajará-Mirim'},
#   'nome': 'Costa Marques',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100098,
#   'microrregiao': {'id': 11006,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Cacoal'},
#   'nome': "Espigão D'Oeste",
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100106,
#   'microrregiao': {'id': 11002,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Madeira-Guaporé'},
#    'nome': 'Guajará-Mirim'},
#   'nome': 'Guajará-Mirim',
#   'regiao-imediata': {'id': 110001,
#    'nome': 'Porto Velho',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100114,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Jaru',
#   'regiao-imediata': {'id': 110003,
#    'nome': 'Jaru',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100122,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Ji-Paraná',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100130,
#   'microrregiao': {'id': 11003,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ariquemes'},
#   'nome': "Machadinho D'Oeste",
#   'regiao-imediata': {'id': 110003,
#    'nome': 'Jaru',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100148,
#   'microrregiao': {'id': 11005,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': "Alvorada D'Oeste"},
#   'nome': "Nova Brasilândia D'Oeste",
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100155,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Ouro Preto do Oeste',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100189,
#   'microrregiao': {'id': 11007,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Vilhena'},
#   'nome': 'Pimenta Bueno',
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100205,
#   'microrregiao': {'id': 11001,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Madeira-Guaporé'},
#    'nome': 'Porto Velho'},
#   'nome': 'Porto Velho',
#   'regiao-imediata': {'id': 110001,
#    'nome': 'Porto Velho',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100254,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Presidente Médici',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100262,
#   'microrregiao': {'id': 11003,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ariquemes'},
#   'nome': 'Rio Crespo',
#   'regiao-imediata': {'id': 110002,
#    'nome': 'Ariquemes',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100288,
#   'microrregiao': {'id': 11006,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Cacoal'},
#   'nome': 'Rolim de Moura',
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100296,
#   'microrregiao': {'id': 11006,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Cacoal'},
#   'nome': "Santa Luzia D'Oeste",
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100304,
#   'microrregiao': {'id': 11007,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Vilhena'},
#   'nome': 'Vilhena',
#   'regiao-imediata': {'id': 110006,
#    'nome': 'Vilhena',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100320,
#   'microrregiao': {'id': 11005,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': "Alvorada D'Oeste"},
#   'nome': 'São Miguel do Guaporé',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100338,
#   'microrregiao': {'id': 11001,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Madeira-Guaporé'},
#    'nome': 'Porto Velho'},
#   'nome': 'Nova Mamoré',
#   'regiao-imediata': {'id': 110001,
#    'nome': 'Porto Velho',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100346,
#   'microrregiao': {'id': 11005,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': "Alvorada D'Oeste"},
#   'nome': "Alvorada D'Oeste",
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100379,
#   'microrregiao': {'id': 11006,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Cacoal'},
#   'nome': 'Alto Alegre dos Parecis',
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100403,
#   'microrregiao': {'id': 11003,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ariquemes'},
#   'nome': 'Alto Paraíso',
#   'regiao-imediata': {'id': 110002,
#    'nome': 'Ariquemes',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100452,
#   'microrregiao': {'id': 11001,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Madeira-Guaporé'},
#    'nome': 'Porto Velho'},
#   'nome': 'Buritis',
#   'regiao-imediata': {'id': 110002,
#    'nome': 'Ariquemes',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100502,
#   'microrregiao': {'id': 11006,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Cacoal'},
#   'nome': 'Novo Horizonte do Oeste',
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100601,
#   'microrregiao': {'id': 11003,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ariquemes'},
#   'nome': 'Cacaulândia',
#   'regiao-imediata': {'id': 110002,
#    'nome': 'Ariquemes',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100700,
#   'microrregiao': {'id': 11001,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Madeira-Guaporé'},
#    'nome': 'Porto Velho'},
#   'nome': 'Campo Novo de Rondônia',
#   'regiao-imediata': {'id': 110002,
#    'nome': 'Ariquemes',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100809,
#   'microrregiao': {'id': 11001,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Madeira-Guaporé'},
#    'nome': 'Porto Velho'},
#   'nome': 'Candeias do Jamari',
#   'regiao-imediata': {'id': 110001,
#    'nome': 'Porto Velho',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1100908,
#   'microrregiao': {'id': 11006,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Cacoal'},
#   'nome': 'Castanheiras',
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100924,
#   'microrregiao': {'id': 11007,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Vilhena'},
#   'nome': 'Chupinguaia',
#   'regiao-imediata': {'id': 110006,
#    'nome': 'Vilhena',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1100940,
#   'microrregiao': {'id': 11001,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Madeira-Guaporé'},
#    'nome': 'Porto Velho'},
#   'nome': 'Cujubim',
#   'regiao-imediata': {'id': 110002,
#    'nome': 'Ariquemes',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1101005,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Governador Jorge Teixeira',
#   'regiao-imediata': {'id': 110003,
#    'nome': 'Jaru',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1101104,
#   'microrregiao': {'id': 11001,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Madeira-Guaporé'},
#    'nome': 'Porto Velho'},
#   'nome': 'Itapuã do Oeste',
#   'regiao-imediata': {'id': 110001,
#    'nome': 'Porto Velho',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1101203,
#   'microrregiao': {'id': 11006,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Cacoal'},
#   'nome': 'Ministro Andreazza',
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101302,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Mirante da Serra',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101401,
#   'microrregiao': {'id': 11003,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ariquemes'},
#   'nome': 'Monte Negro',
#   'regiao-imediata': {'id': 110002,
#    'nome': 'Ariquemes',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1101435,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Nova União',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101450,
#   'microrregiao': {'id': 11007,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Vilhena'},
#   'nome': 'Parecis',
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101468,
#   'microrregiao': {'id': 11008,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Colorado do Oeste'},
#   'nome': 'Pimenteiras do Oeste',
#   'regiao-imediata': {'id': 110006,
#    'nome': 'Vilhena',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101476,
#   'microrregiao': {'id': 11007,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Vilhena'},
#   'nome': 'Primavera de Rondônia',
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101484,
#   'microrregiao': {'id': 11007,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Vilhena'},
#   'nome': "São Felipe D'Oeste",
#   'regiao-imediata': {'id': 110005,
#    'nome': 'Cacoal',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101492,
#   'microrregiao': {'id': 11002,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Madeira-Guaporé'},
#    'nome': 'Guajará-Mirim'},
#   'nome': 'São Francisco do Guaporé',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101500,
#   'microrregiao': {'id': 11005,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': "Alvorada D'Oeste"},
#   'nome': 'Seringueiras',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101559,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Teixeirópolis',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101609,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Theobroma',
#   'regiao-imediata': {'id': 110003,
#    'nome': 'Jaru',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1101708,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Urupá',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1101757,
#   'microrregiao': {'id': 11003,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ariquemes'},
#   'nome': 'Vale do Anari',
#   'regiao-imediata': {'id': 110003,
#    'nome': 'Jaru',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1101,
#     'nome': 'Porto Velho'}}},
#  {'id': 1101807,
#   'microrregiao': {'id': 11004,
#    'mesorregiao': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Leste Rondoniense'},
#    'nome': 'Ji-Paraná'},
#   'nome': 'Vale do Paraíso',
#   'regiao-imediata': {'id': 110004,
#    'nome': 'Ji-Paraná',
#    'regiao-intermediaria': {'UF': {'id': 11,
#      'nome': 'Rondônia',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'RO'},
#     'id': 1102,
#     'nome': 'Ji-Paraná'}}},
#  {'id': 1200013,
#   'microrregiao': {'id': 12004,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Rio Branco'},
#   'nome': 'Acrelândia',
#   'regiao-imediata': {'id': 120001,
#    'nome': 'Rio Branco',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200054,
#   'microrregiao': {'id': 12005,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Brasiléia'},
#   'nome': 'Assis Brasil',
#   'regiao-imediata': {'id': 120002,
#    'nome': 'Brasiléia',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200104,
#   'microrregiao': {'id': 12005,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Brasiléia'},
#   'nome': 'Brasiléia',
#   'regiao-imediata': {'id': 120002,
#    'nome': 'Brasiléia',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200138,
#   'microrregiao': {'id': 12004,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Rio Branco'},
#   'nome': 'Bujari',
#   'regiao-imediata': {'id': 120001,
#    'nome': 'Rio Branco',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200179,
#   'microrregiao': {'id': 12004,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Rio Branco'},
#   'nome': 'Capixaba',
#   'regiao-imediata': {'id': 120001,
#    'nome': 'Rio Branco',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200203,
#   'microrregiao': {'id': 12001,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Vale do Juruá'},
#    'nome': 'Cruzeiro do Sul'},
#   'nome': 'Cruzeiro do Sul',
#   'regiao-imediata': {'id': 120004,
#    'nome': 'Cruzeiro do Sul',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Cruzeiro do Sul'}}},
#  {'id': 1200252,
#   'microrregiao': {'id': 12005,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Brasiléia'},
#   'nome': 'Epitaciolândia',
#   'regiao-imediata': {'id': 120002,
#    'nome': 'Brasiléia',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200302,
#   'microrregiao': {'id': 12002,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Vale do Juruá'},
#    'nome': 'Tarauacá'},
#   'nome': 'Feijó',
#   'regiao-imediata': {'id': 120005,
#    'nome': 'Tarauacá',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Cruzeiro do Sul'}}},
#  {'id': 1200328,
#   'microrregiao': {'id': 12002,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Vale do Juruá'},
#    'nome': 'Tarauacá'},
#   'nome': 'Jordão',
#   'regiao-imediata': {'id': 120005,
#    'nome': 'Tarauacá',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Cruzeiro do Sul'}}},
#  {'id': 1200336,
#   'microrregiao': {'id': 12001,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Vale do Juruá'},
#    'nome': 'Cruzeiro do Sul'},
#   'nome': 'Mâncio Lima',
#   'regiao-imediata': {'id': 120004,
#    'nome': 'Cruzeiro do Sul',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Cruzeiro do Sul'}}},
#  {'id': 1200344,
#   'microrregiao': {'id': 12003,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Sena Madureira'},
#   'nome': 'Manoel Urbano',
#   'regiao-imediata': {'id': 120003,
#    'nome': 'Sena Madureira',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200351,
#   'microrregiao': {'id': 12001,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Vale do Juruá'},
#    'nome': 'Cruzeiro do Sul'},
#   'nome': 'Marechal Thaumaturgo',
#   'regiao-imediata': {'id': 120004,
#    'nome': 'Cruzeiro do Sul',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Cruzeiro do Sul'}}},
#  {'id': 1200385,
#   'microrregiao': {'id': 12004,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Rio Branco'},
#   'nome': 'Plácido de Castro',
#   'regiao-imediata': {'id': 120001,
#    'nome': 'Rio Branco',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200393,
#   'microrregiao': {'id': 12001,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Vale do Juruá'},
#    'nome': 'Cruzeiro do Sul'},
#   'nome': 'Porto Walter',
#   'regiao-imediata': {'id': 120004,
#    'nome': 'Cruzeiro do Sul',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Cruzeiro do Sul'}}},
#  {'id': 1200401,
#   'microrregiao': {'id': 12004,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Rio Branco'},
#   'nome': 'Rio Branco',
#   'regiao-imediata': {'id': 120001,
#    'nome': 'Rio Branco',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200427,
#   'microrregiao': {'id': 12001,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Vale do Juruá'},
#    'nome': 'Cruzeiro do Sul'},
#   'nome': 'Rodrigues Alves',
#   'regiao-imediata': {'id': 120004,
#    'nome': 'Cruzeiro do Sul',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Cruzeiro do Sul'}}},
#  {'id': 1200435,
#   'microrregiao': {'id': 12003,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Sena Madureira'},
#   'nome': 'Santa Rosa do Purus',
#   'regiao-imediata': {'id': 120003,
#    'nome': 'Sena Madureira',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200450,
#   'microrregiao': {'id': 12004,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Rio Branco'},
#   'nome': 'Senador Guiomard',
#   'regiao-imediata': {'id': 120001,
#    'nome': 'Rio Branco',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200500,
#   'microrregiao': {'id': 12003,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Sena Madureira'},
#   'nome': 'Sena Madureira',
#   'regiao-imediata': {'id': 120003,
#    'nome': 'Sena Madureira',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200609,
#   'microrregiao': {'id': 12002,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Vale do Juruá'},
#    'nome': 'Tarauacá'},
#   'nome': 'Tarauacá',
#   'regiao-imediata': {'id': 120005,
#    'nome': 'Tarauacá',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Cruzeiro do Sul'}}},
#  {'id': 1200708,
#   'microrregiao': {'id': 12005,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Brasiléia'},
#   'nome': 'Xapuri',
#   'regiao-imediata': {'id': 120002,
#    'nome': 'Brasiléia',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1200807,
#   'microrregiao': {'id': 12004,
#    'mesorregiao': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1202,
#     'nome': 'Vale do Acre'},
#    'nome': 'Rio Branco'},
#   'nome': 'Porto Acre',
#   'regiao-imediata': {'id': 120001,
#    'nome': 'Rio Branco',
#    'regiao-intermediaria': {'UF': {'id': 12,
#      'nome': 'Acre',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AC'},
#     'id': 1201,
#     'nome': 'Rio Branco'}}},
#  {'id': 1300029,
#   'microrregiao': {'id': 13005,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1303,
#     'nome': 'Centro Amazonense'},
#    'nome': 'Tefé'},
#   'nome': 'Alvarães',
#   'regiao-imediata': {'id': 130005,
#    'nome': 'Tefé',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1302,
#     'nome': 'Tefé'}}},
#  {'id': 1300060,
#   'microrregiao': {'id': 13003,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1302,
#     'nome': 'Sudoeste Amazonense'},
#    'nome': 'Alto Solimões'},
#   'nome': 'Amaturá',
#   'regiao-imediata': {'id': 130006,
#    'nome': 'Tabatinga',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1302,
#     'nome': 'Tefé'}}},
#  {'id': 1300086,
#   'microrregiao': {'id': 13006,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1303,
#     'nome': 'Centro Amazonense'},
#    'nome': 'Coari'},
#   'nome': 'Anamã',
#   'regiao-imediata': {'id': 130004,
#    'nome': 'Manacapuru',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1301,
#     'nome': 'Manaus'}}},
#  {'id': 1300102,
#   'microrregiao': {'id': 13006,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1303,
#     'nome': 'Centro Amazonense'},
#    'nome': 'Coari'},
#   'nome': 'Anori',
#   'regiao-imediata': {'id': 130003,
#    'nome': 'Coari',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1301,
#     'nome': 'Manaus'}}},
#  {'id': 1300144,
#   'microrregiao': {'id': 13013,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1304,
#     'nome': 'Sul Amazonense'},
#    'nome': 'Madeira'},
#   'nome': 'Apuí',
#   'regiao-imediata': {'id': 130009,
#    'nome': 'Manicoré',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1303,
#     'nome': 'Lábrea'}}},
#  {'id': 1300201,
#   'microrregiao': {'id': 13003,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1302,
#     'nome': 'Sudoeste Amazonense'},
#    'nome': 'Alto Solimões'},
#   'nome': 'Atalaia do Norte',
#   'regiao-imediata': {'id': 130006,
#    'nome': 'Tabatinga',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1302,
#     'nome': 'Tefé'}}},
#  {'id': 1300300,
#   'microrregiao': {'id': 13007,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1303,
#     'nome': 'Centro Amazonense'},
#    'nome': 'Manaus'},
#   'nome': 'Autazes',
#   'regiao-imediata': {'id': 130001,
#    'nome': 'Manaus',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1301,
#     'nome': 'Manaus'}}},
#  {'id': 1300409,
#   'microrregiao': {'id': 13001,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1301,
#     'nome': 'Norte Amazonense'},
#    'nome': 'Rio Negro'},
#   'nome': 'Barcelos',
#   'regiao-imediata': {'id': 130002,
#    'nome': 'São Gabriel da Cachoeira',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1301,
#     'nome': 'Manaus'}}},
#  {'id': 1300508,
#   'microrregiao': {'id': 13010,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1303,
#     'nome': 'Centro Amazonense'},
#    'nome': 'Parintins'},
#   'nome': 'Barreirinha',
#   'regiao-imediata': {'id': 130010,
#    'nome': 'Parintins',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1304,
#     'nome': 'Parintins'}}},
#  {'id': 1300607,
#   'microrregiao': {'id': 13003,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1302,
#     'nome': 'Sudoeste Amazonense'},
#    'nome': 'Alto Solimões'},
#   'nome': 'Benjamin Constant',
#   'regiao-imediata': {'id': 130006,
#    'nome': 'Tabatinga',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1302,
#     'nome': 'Tefé'}}},
#  {'id': 1300631,
#   'microrregiao': {'id': 13006,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1303,
#     'nome': 'Centro Amazonense'},
#    'nome': 'Coari'},
#   'nome': 'Beruri',
#   'regiao-imediata': {'id': 130003,
#    'nome': 'Coari',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1301,
#     'nome': 'Manaus'}}},
#  {'id': 1300680,
#   'microrregiao': {'id': 13010,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1303,
#     'nome': 'Centro Amazonense'},
#    'nome': 'Parintins'},
#   'nome': 'Boa Vista do Ramos',
#   'regiao-imediata': {'id': 130010,
#    'nome': 'Parintins',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1304,
#     'nome': 'Parintins'}}},
#  {'id': 1300706,
#   'microrregiao': {'id': 13011,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1304,
#     'nome': 'Sul Amazonense'},
#    'nome': 'Boca do Acre'},
#   'nome': 'Boca do Acre',
#   'regiao-imediata': {'id': 130008,
#    'nome': 'Lábrea',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1303,
#     'nome': 'Lábrea'}}},
#  {'id': 1300805,
#   'microrregiao': {'id': 13013,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1304,
#     'nome': 'Sul Amazonense'},
#    'nome': 'Madeira'},
#   'nome': 'Borba',
#   'regiao-imediata': {'id': 130001,
#    'nome': 'Manaus',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1301,
#     'nome': 'Manaus'}}},
#  {'id': 1300839,
#   'microrregiao': {'id': 13006,
#    'mesorregiao': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1303,
#     'nome': 'Centro Amazonense'},
#    'nome': 'Coari'},
#   'nome': 'Caapiranga',
#   'regiao-imediata': {'id': 130004,
#    'nome': 'Manacapuru',
#    'regiao-intermediaria': {'UF': {'id': 13,
#      'nome': 'Amazonas',
#      'regiao': {'id': 1, 'nome': 'Norte', 'sigla': 'N'},
#      'sigla': 'AM'},
#     'id': 1301,
# ...
#      'sigla': 'CE'},
#     'id': 2303,
#     'nome': 'Iguatu'}}},
#  {'id': 2305803,
#   'microrregiao': {'id': 23006,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Noroeste Cearense'},
#    'nome': 'Ipu'},
#   'nome': 'Ipu',
#   'regiao-imediata': {'id': 230016,
#    'nome': 'São Benedito - Ipu - Guaraciaba do Norte - Tianguá',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2306,
#     'nome': 'Sobral'}}},
#  {'id': 2305902,
#   'microrregiao': {'id': 23006,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Noroeste Cearense'},
#    'nome': 'Ipu'},
#   'nome': 'Ipueiras',
#   'regiao-imediata': {'id': 230016,
#    'nome': 'São Benedito - Ipu - Guaraciaba do Norte - Tianguá',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2306,
#     'nome': 'Sobral'}}},
#  {'id': 2306009,
#   'microrregiao': {'id': 23025,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2305,
#     'nome': 'Jaguaribe'},
#    'nome': 'Serra do Pereiro'},
#   'nome': 'Iracema',
#   'regiao-imediata': {'id': 230007,
#    'nome': 'Russas - Limoeiro do Norte',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Quixadá'}}},
#  {'id': 2306108,
#   'microrregiao': {'id': 23005,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Noroeste Cearense'},
#    'nome': 'Sobral'},
#   'nome': 'Irauçuba',
#   'regiao-imediata': {'id': 230005,
#    'nome': 'Itapagé',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Fortaleza'}}},
#  {'id': 2306207,
#   'microrregiao': {'id': 23022,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2305,
#     'nome': 'Jaguaribe'},
#    'nome': 'Litoral de Aracati'},
#   'nome': 'Itaiçaba',
#   'regiao-imediata': {'id': 230008,
#    'nome': 'Aracati',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Quixadá'}}},
#  {'id': 2306256,
#   'microrregiao': {'id': 23016,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2303,
#     'nome': 'Metropolitana de Fortaleza'},
#    'nome': 'Fortaleza'},
#   'nome': 'Itaitinga',
#   'regiao-imediata': {'id': 230001,
#    'nome': 'Fortaleza',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Fortaleza'}}},
#  {'id': 2306306,
#   'microrregiao': {'id': 23010,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Norte Cearense'},
#    'nome': 'Uruburetama'},
#   'nome': 'Itapajé',
#   'regiao-imediata': {'id': 230005,
#    'nome': 'Itapagé',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Fortaleza'}}},
#  {'id': 2306405,
#   'microrregiao': {'id': 23008,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Norte Cearense'},
#    'nome': 'Itapipoca'},
#   'nome': 'Itapipoca',
#   'regiao-imediata': {'id': 230002,
#    'nome': 'Itapipoca',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Fortaleza'}}},
#  {'id': 2306504,
#   'microrregiao': {'id': 23013,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Norte Cearense'},
#    'nome': 'Baturité'},
#   'nome': 'Itapiúna',
#   'regiao-imediata': {'id': 230003,
#    'nome': 'Redenção-Acarape',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Fortaleza'}}},
#  {'id': 2306553,
#   'microrregiao': {'id': 23001,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Noroeste Cearense'},
#    'nome': 'Litoral de Camocim e Acaraú'},
#   'nome': 'Itarema',
#   'regiao-imediata': {'id': 230017,
#    'nome': 'Acaraú',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2306,
#     'nome': 'Sobral'}}},
#  {'id': 2306603,
#   'microrregiao': {'id': 23012,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Norte Cearense'},
#    'nome': 'Canindé'},
#   'nome': 'Itatira',
#   'regiao-imediata': {'id': 230004,
#    'nome': 'Canindé',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Fortaleza'}}},
#  {'id': 2306702,
#   'microrregiao': {'id': 23024,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2305,
#     'nome': 'Jaguaribe'},
#    'nome': 'Médio Jaguaribe'},
#   'nome': 'Jaguaretama',
#   'regiao-imediata': {'id': 230007,
#    'nome': 'Russas - Limoeiro do Norte',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Quixadá'}}},
#  {'id': 2306801,
#   'microrregiao': {'id': 23024,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2305,
#     'nome': 'Jaguaribe'},
#    'nome': 'Médio Jaguaribe'},
#   'nome': 'Jaguaribara',
#   'regiao-imediata': {'id': 230007,
#    'nome': 'Russas - Limoeiro do Norte',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Quixadá'}}},
#  {'id': 2306900,
#   'microrregiao': {'id': 23024,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2305,
#     'nome': 'Jaguaribe'},
#    'nome': 'Médio Jaguaribe'},
#   'nome': 'Jaguaribe',
#   'regiao-imediata': {'id': 230007,
#    'nome': 'Russas - Limoeiro do Norte',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Quixadá'}}},
#  {'id': 2307007,
#   'microrregiao': {'id': 23023,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2305,
#     'nome': 'Jaguaribe'},
#    'nome': 'Baixo Jaguaribe'},
#   'nome': 'Jaguaruana',
#   'regiao-imediata': {'id': 230008,
#    'nome': 'Aracati',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Quixadá'}}},
#  {'id': 2307106,
#   'microrregiao': {'id': 23032,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2307,
#     'nome': 'Sul Cearense'},
#    'nome': 'Cariri'},
#   'nome': 'Jardim',
#   'regiao-imediata': {'id': 230011,
#    'nome': 'Juazeiro do Norte',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2304,
#     'nome': 'Juazeiro do Norte'}}},
#  {'id': 2307205,
#   'microrregiao': {'id': 23033,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2307,
#     'nome': 'Sul Cearense'},
#    'nome': 'Brejo Santo'},
#   'nome': 'Jati',
#   'regiao-imediata': {'id': 230012,
#    'nome': 'Brejo Santo',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2304,
#     'nome': 'Juazeiro do Norte'}}},
#  {'id': 2307254,
#   'microrregiao': {'id': 23001,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Noroeste Cearense'},
#    'nome': 'Litoral de Camocim e Acaraú'},
#   'nome': 'Jijoca de Jericoacoara',
#   'regiao-imediata': {'id': 230017,
#    'nome': 'Acaraú',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2306,
#     'nome': 'Sobral'}}},
#  {'id': 2307304,
#   'microrregiao': {'id': 23032,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2307,
#     'nome': 'Sul Cearense'},
#    'nome': 'Cariri'},
#   'nome': 'Juazeiro do Norte',
#   'regiao-imediata': {'id': 230011,
#    'nome': 'Juazeiro do Norte',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2304,
#     'nome': 'Juazeiro do Norte'}}},
#  {'id': 2307403,
#   'microrregiao': {'id': 23027,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2306,
#     'nome': 'Centro-Sul Cearense'},
#    'nome': 'Várzea Alegre'},
#   'nome': 'Jucás',
#   'regiao-imediata': {'id': 230009,
#    'nome': 'Iguatu',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2303,
#     'nome': 'Iguatu'}}},
#  {'id': 2307502,
#   'microrregiao': {'id': 23028,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2306,
#     'nome': 'Centro-Sul Cearense'},
#    'nome': 'Lavras da Mangabeira'},
#   'nome': 'Lavras da Mangabeira',
#   'regiao-imediata': {'id': 230011,
#    'nome': 'Juazeiro do Norte',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2304,
#     'nome': 'Juazeiro do Norte'}}},
#  {'id': 2307601,
#   'microrregiao': {'id': 23023,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2305,
#     'nome': 'Jaguaribe'},
#    'nome': 'Baixo Jaguaribe'},
#   'nome': 'Limoeiro do Norte',
#   'regiao-imediata': {'id': 230007,
#    'nome': 'Russas - Limoeiro do Norte',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2302,
#     'nome': 'Quixadá'}}},
#  {'id': 2307635,
#   'microrregiao': {'id': 23019,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2304,
#     'nome': 'Sertões Cearenses'},
#    'nome': 'Sertão de Quixeramobim'},
#   'nome': 'Madalena',
#   'regiao-imediata': {'id': 230004,
#    'nome': 'Canindé',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Fortaleza'}}},
#  {'id': 2307650,
#   'microrregiao': {'id': 23016,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2303,
#     'nome': 'Metropolitana de Fortaleza'},
#    'nome': 'Fortaleza'},
#   'nome': 'Maracanaú',
#   'regiao-imediata': {'id': 230001,
#    'nome': 'Fortaleza',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Fortaleza'}}},
#  {'id': 2307700,
#   'microrregiao': {'id': 23016,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2303,
#     'nome': 'Metropolitana de Fortaleza'},
#    'nome': 'Fortaleza'},
#   'nome': 'Maranguape',
#   'regiao-imediata': {'id': 230001,
#    'nome': 'Fortaleza',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Fortaleza'}}},
#  {'id': 2307809,
#   'microrregiao': {'id': 23001,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Noroeste Cearense'},
#    'nome': 'Litoral de Camocim e Acaraú'},
#   'nome': 'Marco',
#   'regiao-imediata': {'id': 230017,
#    'nome': 'Acaraú',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2306,
#     'nome': 'Sobral'}}},
#  {'id': 2307908,
#   'microrregiao': {'id': 23001,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Noroeste Cearense'},
#    'nome': 'Litoral de Camocim e Acaraú'},
#   'nome': 'Martinópole',
#   'regiao-imediata': {'id': 230015,
#    'nome': 'Sobral',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2306,
#     'nome': 'Sobral'}}},
#  {'id': 2308005,
#   'microrregiao': {'id': 23005,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2301,
#     'nome': 'Noroeste Cearense'},
#    'nome': 'Sobral'},
#   'nome': 'Massapê',
#   'regiao-imediata': {'id': 230015,
#    'nome': 'Sobral',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2306,
#     'nome': 'Sobral'}}},
#  {'id': 2308104,
#   'microrregiao': {'id': 23031,
#    'mesorregiao': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2307,
#     'nome': 'Sul Cearense'},
#    'nome': 'Barro'},
#   'nome': 'Mauriti',
#   'regiao-imediata': {'id': 230012,
#    'nome': 'Brejo Santo',
#    'regiao-intermediaria': {'UF': {'id': 23,
#      'nome': 'Ceará',
#      'regiao': {'id': 2, 'nome': 'Nordeste', 'sigla': 'NE'},
#      'sigla': 'CE'},
#     'id': 2304,
#     'nome': 'Juazeiro do Norte'}}},
#  ...]

# %% [markdown]
# **Connect to database in Mongodb Cloud**

# %%
client = pymongo.MongoClient("mongodb+srv://estudante_igti:SRwkJTDz2nA28ME9@unicluster.ixhvw.mongodb.net/ibge?retryWrites=true&w=majority")

# %%
banco = client.ibge
album = banco.pnadc20203
album.find_one()
# Out:
# {'_id': ObjectId('600ce0685daa95c6616007ac'),
#  'ano': 2020,
#  'anosesco': 0.0,
#  'cor': 'Parda',
#  'graduacao': None,
#  'horastrab': None,
#  'idade': 62,
#  'ocup': None,
#  'renda': None,
#  'sexo': 'Mulher',
#  'trab': 'Pessoas fora da força de trabalho',
#  'trimestre': 3,
#  'uf': 'Acre'}

# %% [markdown]
# **Downloading the pnadc20203 (in database ibge) collection and converting it to the json file**

# %%
cursor = album.find({})
with open('pnadc20203.json', 'w') as file:
        file.write('[')
        for document in cursor:
            file.write(dumps(document))
            file.write(',')
        file.write(']')

# %% [markdown]
# **Extracting the Region, State and county of ibge API and converting to Json**

# %%
with open('dataRegiao.json', 'w') as outfile:
    json.dump(dataRegiao.json(), outfile)
with open('dataEstado.json', 'w') as outfile:
    json.dump(dataEstado.json(), outfile)    
with open('dataMunicipio.json', 'w') as outfile:
    json.dump(dataMunicipio.json(), outfile)

# %% [markdown]
# **Loading JSON files to S3 AWS**

# %%
ACCESS_KEY = 'AKIAIHE6OORDDVZOH3NA'
SECRET_KEY = '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'


def upload_to_aws(local_file, bucket, s3_file):
    s3 = boto3.client('s3', aws_access_key_id=ACCESS_KEY,
                      aws_secret_access_key=SECRET_KEY)

    try:
        s3.upload_file(local_file, bucket, s3_file)
        print("Upload Successful")
        return True
    except FileNotFoundError:
        print("The file was not found")
        return False
    except NoCredentialsError:
        print("Credentials not available")
        return False

# Uploading files with the function 'upload_to_aws' created before
uploaded = upload_to_aws('dataRegiao.json', 'igti-bootcamp-ed-2021-evangelista', 'regiao.json')
uploaded = upload_to_aws('dataEstado.json', 'igti-bootcamp-ed-2021-evangelista', 'estado.json')
uploaded = upload_to_aws('dataMunicipio.json', 'igti-bootcamp-ed-2021-evangelista', 'municipio.json')
uploaded = upload_to_aws('pnadc20203.json', 'igti-bootcamp-ed-2021-evangelista', 'mulheres.json')
# Out:
# Upload Successful
# Upload Successful
# Upload Successful
# Upload Successful
